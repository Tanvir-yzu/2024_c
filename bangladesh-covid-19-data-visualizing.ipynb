# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/kaggle/input/bangladesh/Bangladesh.csv')


data.shape
# Out:
# (949, 67)

# %%
data['date'] = pd.to_datetime(data['date'])



data.head()
# Out:
#   iso_code continent    location       date  total_cases  new_cases  \
# 0       BD      Asia  Bangladesh 2020-02-25            2          2
# 1       BD      Asia  Bangladesh 2020-02-26            2          0
# 2       BD      Asia  Bangladesh 2020-02-27            2          0
# 3       BD      Asia  Bangladesh 2020-02-28            4          2
# 4       BD      Asia  Bangladesh 2020-02-29            4          0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             2.8          36.7                  59.607
# 1             2.8          36.7                  59.607
# 2             2.8          36.7                  59.607
# 3             2.8          36.7                  59.607
# 4             2.8          36.7                  59.607
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.6            67.27                    0.557
# 1                         0.6            67.27                    0.557
# 2                         0.6            67.27                    0.557
# 3                         0.6            67.27                    0.557
# 4                         0.6            67.27                    0.557
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
print(data.isnull().sum())



data_numeric = data.select_dtypes(include=['float64', 'int64'])

data[data_numeric.columns] = data_numeric.interpolate(method='linear', limit_direction='forward')



data.ffill(inplace=True)
# Out:
# iso_code                                     0
# continent                                    0
# location                                     0
# date                                         0
# total_cases                                  0
#                                           ...
# human_development_index                      0
# excess_mortality_cumulative_absolute       949
# excess_mortality_cumulative                949
# excess_mortality                           949
# excess_mortality_cumulative_per_million    949
# Length: 67, dtype: int64

# %%
data.describe()
# Out:
#                       date   total_cases     new_cases  new_cases_smoothed  \
# count                  949  9.490000e+02    949.000000          944.000000
# mean   2021-06-13 00:00:00  8.722141e+05   1657.110643         1665.665092
# min    2020-02-25 00:00:00  2.000000e+00      0.000000            0.000000
# 25%    2020-10-19 00:00:00  3.240340e+05    336.000000          399.286000
# 50%    2021-06-13 00:00:00  9.421890e+05    991.000000          999.571500
# 75%    2022-02-05 00:00:00  1.459773e+06   2545.000000         2563.392750
# max    2022-09-30 00:00:00  1.572598e+06  12073.000000         7198.000000
# std                    NaN  5.484459e+05   1734.552540         1638.973627
#
#        total_deaths  new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count    927.000000  927.000000           922.000000               949.000000
# mean   18756.812298   33.026969            33.199433              3769.257255
# min        2.000000    0.000000             0.000000                 0.009000
# 25%     6908.000000    4.000000             4.857000              1400.307000
# 50%    22152.000000   19.000000            22.714500              4071.652000
# 75%    29709.000000   54.000000            52.071500              6308.382000
# max    30616.000000  313.000000           140.286000              6795.953000
# std    10990.375727   37.510406            33.588259              2370.098996
#
#        new_cases_per_million  new_cases_smoothed_per_million  ...  \
# count             949.000000                      944.000000  ...
# mean                7.161190                        7.198125  ...
# min                 0.000000                        0.000000  ...
# 25%                 1.452000                        1.725500  ...
# 50%                 4.283000                        4.320000  ...
# 75%                10.998000                       11.077750  ...
# max                52.173000                       31.106000  ...
# std                 7.495837                        7.082775  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# count           949.0         949.0            9.490000e+02
# mean              2.8          36.7            5.960700e+01
# min               2.8          36.7            5.960700e+01
# 25%               2.8          36.7            5.960700e+01
# 50%               2.8          36.7            5.960700e+01
# 75%               2.8          36.7            5.960700e+01
# max               2.8          36.7            5.960700e+01
# std               0.0           0.0            2.132752e-14
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count                9.490000e+02     9.490000e+02             9.490000e+02
# mean                 6.000000e-01     6.727000e+01             5.570000e-01
# min                  6.000000e-01     6.727000e+01             5.570000e-01
# 25%                  6.000000e-01     6.727000e+01             5.570000e-01
# 50%                  6.000000e-01     6.727000e+01             5.570000e-01
# 75%                  6.000000e-01     6.727000e+01             5.570000e-01
# max                  6.000000e-01     6.727000e+01             5.570000e-01
# std                  1.110808e-16     1.421835e-14             1.110808e-16
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# count                                   0.0                          0.0
# mean                                    NaN                          NaN
# min                                     NaN                          NaN
# 25%                                     NaN                          NaN
# 50%                                     NaN                          NaN
# 75%                                     NaN                          NaN
# max                                     NaN                          NaN
# std                                     NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# count               0.0                                      0.0
# mean                NaN                                      NaN
# min                 NaN                                      NaN
# 25%                 NaN                                      NaN
# 50%                 NaN                                      NaN
# 75%                 NaN                                      NaN
# max                 NaN                                      NaN
# std                 NaN                                      NaN
#
# [8 rows x 63 columns]

# %%
plt.figure(figsize=(10, 6))

plt.fill_between(data['date'], data['total_cases'], color='Slateblue', alpha=0.2)

plt.plot(data['date'], data['total_cases'], label='Total Cases', color='Slateblue', linewidth=2)

plt.title('COVID-19 Total Cases in Bangladesh Over Time')

plt.xlabel('Date')

plt.ylabel('Total Cases')

plt.grid(True, which='both', linestyle='--')

plt.legend()

plt.show()

# %%
# new daily cases

plt.figure(figsize=(10, 6))

plt.fill_between(data['date'], data['new_cases'], color='Slateblue', alpha=0.3)

plt.plot(data['date'], data['new_cases'], label='New Cases', color='Slateblue', linewidth=2)

plt.title('Daily New COVID-19 Cases in Bangladesh')

plt.xlabel('Date')

plt.ylabel('New Cases')

plt.grid(True, which='both', linestyle='--')

plt.legend()

plt.show()

# %%
# total deaths over time

plt.figure(figsize=(10, 6))

plt.fill_between(data['date'], data['total_deaths'], color='red', alpha=0.2)

plt.plot(data['date'], data['total_deaths'], label='Total Deaths', color='red', linewidth=2)

plt.title('Total COVID-19 Deaths in bangladesh Over Time')

plt.xlabel('Date')

plt.ylabel('Total Deaths')

plt.grid(True, which='both', linestyle='--')

plt.legend()

plt.show()

# %%
# Plotting daily deaths over time

plt.figure(figsize=(10, 6))

plt.fill_between(data['date'], data['new_deaths'], color='red', alpha=0.3)

plt.plot(data['date'], data['new_deaths'], color='red', label='Daily Deaths')

plt.title('Daily COVID-19 Deaths in Bangladesh')

plt.xlabel('Date')

plt.ylabel('Number of Deaths')

plt.grid(True, which='both', linestyle='--')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.fill_between(data['date'], data['reproduction_rate'], color='purple', alpha=0.2)

plt.plot(data['date'], data['reproduction_rate'], label='Reproduction Rate', color='purple', linewidth=2)

plt.title('COVID-19 Reproduction Rate in Bangladesh Over Time')

plt.xlabel('Date')

plt.ylabel('Reproduction Rate')

plt.grid(True, which='both', linestyle='--')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.fill_between(data['date'], data['total_vaccinations'], color='orange', alpha=0.2)

plt.plot(data['date'], data['total_vaccinations'], label='Total Vaccinations', color='orange', linewidth=2)

plt.title('COVID-19 Total Vaccinations in Bangladesh Over Time')

plt.xlabel('Date')

plt.ylabel('Total Vaccinations')

plt.grid(True, which='both', linestyle='--')

plt.legend()

plt.show()

# %%
vaccinated = data['people_vaccinated'].max()

fully_vaccinated = data['people_fully_vaccinated'].max()

total_population = data['population'].max()



labels = ['Vaccinated', 'Fully Vaccinated', 'Unvaccinated']

sizes = [vaccinated, fully_vaccinated, total_population - vaccinated]



plt.figure(figsize=(5, 5))

plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['lightgreen', 'green', 'red'], startangle=90)

plt.title('Vaccination Progress in Bangladesh')

plt.show()
